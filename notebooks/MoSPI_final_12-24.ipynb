# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv(r"C:\Users\himan\Education1\Projects\MoSPI_CPI\Data\raw\cpi Group data_initial data.csv")

# %%
data.head(25)
# Out:
#     BaseYear  Year     Month      State    Sector  \
# 0       2012  2024  December  All India  Combined
# 1       2012  2024  December  All India  Combined
# 2       2012  2024  December  All India  Combined
# 3       2012  2024  December  All India  Combined
# 4       2012  2024  December  All India  Combined
# 5       2012  2024  December  All India  Combined
# 6       2012  2024  December  All India  Combined
# 7       2012  2024  December  All India  Combined
# 8       2012  2024  December  All India  Combined
# 9       2012  2024  December  All India  Combined
# 10      2012  2024  December  All India  Combined
# 11      2012  2024  December  All India  Combined
# 12      2012  2024  December  All India  Combined
# 13      2012  2024  December  All India  Combined
# 14      2012  2024  December  All India  Combined
# 15      2012  2024  December  All India  Combined
# 16      2012  2024  December  All India  Combined
# 17      2012  2024  December  All India  Combined
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2024  December    All India  Combined  Food and Beverages
# 1           2012  2024  December    All India  Combined  Food and Beverages
# 2           2012  2024  December    All India  Combined  Food and Beverages
# 3           2012  2024  December    All India  Combined  Food and Beverages
# 4           2012  2024  December    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 215956      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215957      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215958      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215959      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215960      2012  2014   January  West Bengal     Urban       Miscellaneous
#
# ...

# %%
data.isnull().sum()
# Out:
# BaseYear         0
# Year             0
# Month            0
# State            0
# Sector           0
# Group            0
# SubGroup         0
# Index            0
# Inflation (%)    0
# dtype: int64

# %%
data["SubGroup"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_22844\403528206.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data["SubGroup"].replace({"*" : np.nan}, inplace=True)
# 0                 Cereals and Products
# 1                        Meat and Fish
# 2                                  Egg
# ...

# %%
data["Index"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_22844\1331821987.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data["Index"].replace({"*" : np.nan}, inplace=True)
# 0         198.1
# 1         222.5
# 2         212.1
# 3         190.6
# 4         258.3
#           ...
# 215956    117.4
# 215957    110.3
# ...

# %%
data["Inflation (%)"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_22844\2710611657.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data["Inflation (%)"].replace({"*" : np.nan}, inplace=True)
# 0          6.51
# 1           5.3
# 2          6.85
# 3           8.6
# 4         26.56
#           ...
# 215956    12.13
# 215957     5.75
# ...

# %%
data.tail(15)
# Out:
#         BaseYear  Year    Month        State Sector  \
# 215946      2012  2014  January  West Bengal  Urban
# 215947      2012  2014  January  West Bengal  Urban
# 215948      2012  2014  January  West Bengal  Urban
# 215949      2012  2014  January  West Bengal  Urban
# 215950      2012  2014  January  West Bengal  Urban
# 215951      2012  2014  January  West Bengal  Urban
# 215952      2012  2014  January  West Bengal  Urban
# 215953      2012  2014  January  West Bengal  Urban
# 215954      2012  2014  January  West Bengal  Urban
# 215955      2012  2014  January  West Bengal  Urban
# 215956      2012  2014  January  West Bengal  Urban
# 215957      2012  2014  January  West Bengal  Urban
# 215958      2012  2014  January  West Bengal  Urban
# 215959      2012  2014  January  West Bengal  Urban
# 215960      2012  2014  January  West Bengal  Urban
#
#                                Group                             SubGroup  \
# ...

# %%
data[data["Index"] == "*"]
# Out:
#         BaseYear  Year     Month                        State    Sector  \
# 35          2012  2024  December                    All India     Rural
# 66          2012  2024  December  Andaman and Nicobar Islands  Combined
# 72          2012  2024  December  Andaman and Nicobar Islands     Rural
# 95          2012  2024  December               Andhra Pradesh  Combined
# 116         2012  2024  December               Andhra Pradesh     Rural
# ...          ...   ...       ...                          ...       ...
# 215807      2012  2014   January                  Uttarakhand     Rural
# 215849      2012  2014   January                Uttar Pradesh  Combined
# 215870      2012  2014   January                Uttar Pradesh     Rural
# 215912      2012  2014   January                  West Bengal  Combined
# 215933      2012  2014   January                  West Bengal     Rural
#
#           Group SubGroup Index Inflation (%)
# 35      Housing        *     *             *
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215961 entries, 0 to 215960
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   BaseYear       215961 non-null  int64
#  1   Year           215961 non-null  int64
#  2   Month          215961 non-null  str
#  3   State          215961 non-null  str
#  4   Sector         215961 non-null  str
#  5   Group          215961 non-null  str
#  6   SubGroup       215961 non-null  str
#  7   Index          215961 non-null  str
#  8   Inflation (%)  215961 non-null  str
# dtypes: int64(2), str(7)
# memory usage: 14.8 MB

# %%
data.isnull().sum()
# Out:
# BaseYear         0
# Year             0
# Month            0
# State            0
# Sector           0
# Group            0
# SubGroup         0
# Index            0
# Inflation (%)    0
# dtype: int64

# %%
data.loc[data["Group"] == "Food and Beverages", "SubGroup"] = data.loc[data["Group"] == "Food and Beverages", "SubGroup"].fillna("Miscellaneous")

# %%
data[data["Group"] == "Food and Beverages"]
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2024  December    All India  Combined  Food and Beverages
# 1           2012  2024  December    All India  Combined  Food and Beverages
# 2           2012  2024  December    All India  Combined  Food and Beverages
# 3           2012  2024  December    All India  Combined  Food and Beverages
# 4           2012  2024  December    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 215945      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215946      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215947      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215948      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215949      2012  2014   January  West Bengal     Urban  Food and Beverages
#
# ...

# %%
data.head(10)
# Out:
#    BaseYear  Year     Month      State    Sector               Group  \
# 0      2012  2024  December  All India  Combined  Food and Beverages
# 1      2012  2024  December  All India  Combined  Food and Beverages
# 2      2012  2024  December  All India  Combined  Food and Beverages
# 3      2012  2024  December  All India  Combined  Food and Beverages
# 4      2012  2024  December  All India  Combined  Food and Beverages
# 5      2012  2024  December  All India  Combined  Food and Beverages
# 6      2012  2024  December  All India  Combined  Food and Beverages
# 7      2012  2024  December  All India  Combined  Food and Beverages
# 8      2012  2024  December  All India  Combined  Food and Beverages
# 9      2012  2024  December  All India  Combined  Food and Beverages
#
#                               SubGroup  Index Inflation (%)
# 0                 Cereals and Products  198.1          6.51
# 1                        Meat and Fish  222.5           5.3
# ...

# %%
data.iloc[60:80]
# Out:
#     BaseYear  Year     Month                        State    Sector  \
# 60      2012  2024  December                    All India     Urban
# 61      2012  2024  December                    All India     Urban
# 62      2012  2024  December                    All India     Urban
# 63      2012  2024  December  Andaman and Nicobar Islands  Combined
# 64      2012  2024  December  Andaman and Nicobar Islands  Combined
# 65      2012  2024  December  Andaman and Nicobar Islands  Combined
# 66      2012  2024  December  Andaman and Nicobar Islands  Combined
# 67      2012  2024  December  Andaman and Nicobar Islands  Combined
# 68      2012  2024  December  Andaman and Nicobar Islands  Combined
# 69      2012  2024  December  Andaman and Nicobar Islands     Rural
# 70      2012  2024  December  Andaman and Nicobar Islands     Rural
# 71      2012  2024  December  Andaman and Nicobar Islands     Rural
# 72      2012  2024  December  Andaman and Nicobar Islands     Rural
# ...

# %%
data.loc[data["Group"] == "Food and Beverages", "SubGroup"] = data.loc[data["Group"] == "Food and Beverages", "SubGroup"].replace(to_replace="Miscellaneous", value= "Residual")

# %%
data
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2024  December    All India  Combined  Food and Beverages
# 1           2012  2024  December    All India  Combined  Food and Beverages
# 2           2012  2024  December    All India  Combined  Food and Beverages
# 3           2012  2024  December    All India  Combined  Food and Beverages
# 4           2012  2024  December    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 215956      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215957      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215958      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215959      2012  2014   January  West Bengal     Urban       Miscellaneous
# 215960      2012  2014   January  West Bengal     Urban       Miscellaneous
#
# ...

# %%
data.loc[data["Group"] == "Food and Beverages"]
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2024  December    All India  Combined  Food and Beverages
# 1           2012  2024  December    All India  Combined  Food and Beverages
# 2           2012  2024  December    All India  Combined  Food and Beverages
# 3           2012  2024  December    All India  Combined  Food and Beverages
# 4           2012  2024  December    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 215945      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215946      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215947      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215948      2012  2014   January  West Bengal     Urban  Food and Beverages
# 215949      2012  2014   January  West Bengal     Urban  Food and Beverages
#
# ...

# %%
data.loc[data["Group"] == "Pan, Tobacco and Intoxicants", "SubGroup"] = data.loc[data["Group"] == "Pan, Tobacco and Intoxicants", "SubGroup"].fillna("Residual")

# %%
data["Group"].unique()
# Out:
# <StringArray>
# [          'Food and Beverages', 'Pan, Tobacco and Intoxicants',
#         'Clothing and Footwear',                      'Housing',
#                'Fuel and Light',                'Miscellaneous']
# Length: 6, dtype: str

# %%
data.loc[data["Group"] == "Clothing and Footwear", "SubGroup"] = data.loc[data["Group"] == "Clothing and Footwear", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Fuel and Light", "SubGroup"] = data.loc[data["Group"] == "Fuel and Light", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Miscellaneous", "SubGroup"] = data.loc[data["Group"] == "Miscellaneous", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Housing", "SubGroup"] = data.loc[data["Group"] == "Housing", "SubGroup"].fillna("Housing")

# %%
data[60:80]
# Out:
#     BaseYear  Year     Month                        State    Sector  \
# 60      2012  2024  December                    All India     Urban
# 61      2012  2024  December                    All India     Urban
# 62      2012  2024  December                    All India     Urban
# 63      2012  2024  December  Andaman and Nicobar Islands  Combined
# 64      2012  2024  December  Andaman and Nicobar Islands  Combined
# 65      2012  2024  December  Andaman and Nicobar Islands  Combined
# 66      2012  2024  December  Andaman and Nicobar Islands  Combined
# 67      2012  2024  December  Andaman and Nicobar Islands  Combined
# 68      2012  2024  December  Andaman and Nicobar Islands  Combined
# 69      2012  2024  December  Andaman and Nicobar Islands     Rural
# 70      2012  2024  December  Andaman and Nicobar Islands     Rural
# 71      2012  2024  December  Andaman and Nicobar Islands     Rural
# 72      2012  2024  December  Andaman and Nicobar Islands     Rural
# ...

# %%
# Convert Index_i to numeric
data["Index"] = pd.to_numeric(data["Index"], errors="coerce")

# %%
data.loc[data["Index"].isna(), "Index"] = data["Index"].mode()[0]

# %%
# Step 1: Ensure column is numeric
data["Inflation (%)"] = pd.to_numeric(data["Inflation (%)"], errors="coerce")

# Step 2: Fill NaN values with median using loc
data.loc[data["Inflation (%)"].isna(), "Inflation (%)"] = data["Inflation (%)"].median()

# %%
data[203955:203975]
# Out:
#         BaseYear  Year   Month          State    Sector  \
# 203955      2012  2014  August  Uttar Pradesh  Combined
# 203956      2012  2014  August  Uttar Pradesh  Combined
# 203957      2012  2014  August  Uttar Pradesh  Combined
# 203958      2012  2014  August  Uttar Pradesh  Combined
# 203959      2012  2014  August  Uttar Pradesh  Combined
# 203960      2012  2014  August  Uttar Pradesh  Combined
# 203961      2012  2014  August  Uttar Pradesh  Combined
# 203962      2012  2014  August  Uttar Pradesh  Combined
# 203963      2012  2014  August  Uttar Pradesh  Combined
# 203964      2012  2014  August  Uttar Pradesh  Combined
# 203965      2012  2014  August  Uttar Pradesh  Combined
# 203966      2012  2014  August  Uttar Pradesh  Combined
# 203967      2012  2014  August  Uttar Pradesh  Combined
# 203968      2012  2014  August  Uttar Pradesh  Combined
# 203969      2012  2014  August  Uttar Pradesh  Combined
# 203970      2012  2014  August  Uttar Pradesh     Rural
# ...

# %%
data.rename(columns={"BaseYear": "BYear"}, inplace=True)

# %%
data.rename(columns={"Year": "Year_i"}, inplace=True)

# %%
data.rename(columns={"Month": "Month_i"}, inplace=True)

# %%
data.rename(columns={"State": "State_i"}, inplace=True)

# %%
data.rename(columns={"Index": "Index_i"}, inplace=True)

# %%
data.rename(columns={"Inflation (%)": "Inflation"}, inplace=True)

# %%
data.rename(columns={"Group": "Group_i"}, inplace=True)

# %%
data["Index_i"] = pd.to_numeric(data["Index_i"], errors="coerce")

# %%
print(data["Index_i"].isna().sum())
# Out:
# 0

# %%
data["Index_i"] = data["Index_i"].astype(int)
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215961 entries, 0 to 215960
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   BYear      215961 non-null  int64
#  1   Year_i     215961 non-null  int64
#  2   Month_i    215961 non-null  str
#  3   State_i    215961 non-null  str
#  4   Sector     215961 non-null  str
#  5   Group_i    215961 non-null  str
#  6   SubGroup   215961 non-null  str
#  7   Index_i    215961 non-null  int64
#  8   Inflation  215961 non-null  float64
# dtypes: float64(1), int64(3), str(5)
# memory usage: 14.8 MB

# %%
data["Year_i"].value_counts().loc[[2024]]
# Out:
# Year_i
# 2024    20376
# Name: count, dtype: int64

# %%
# Strip any potential whitespace and replace '*' with 'Residual'
data["SubGroup"] = data["SubGroup"].astype(str).str.strip().replace("*", "Residual")

# %%
print(data.loc[data["Year_i"] == 2024, "SubGroup"].unique())
# Out:
# <StringArray>
# [               'Cereals and Products',                       'Meat and Fish',
#                                  'Egg',                              'Fruits',
#                           'Vegetables',                 'Pulses and Products',
#                               'Spices', 'Prepared Meals, Snacks, Sweets etc.',
#              'Non-alcoholic Beverages',                            'Residual',
#                             'Clothing',                            'Footwear',
#         'Household Goods and Services',                              'Health',
#          'Transport and Communication',                           'Education']
# Length: 16, dtype: str

# %%
data[data["Year_i"] == 2014].head(15)
# Out:
#         BYear  Year_i   Month_i    State_i    Sector  \
# 195585   2012    2014  December  All India  Combined
# 195586   2012    2014  December  All India  Combined
# 195587   2012    2014  December  All India  Combined
# 195588   2012    2014  December  All India  Combined
# 195589   2012    2014  December  All India  Combined
# 195590   2012    2014  December  All India  Combined
# 195591   2012    2014  December  All India  Combined
# 195592   2012    2014  December  All India  Combined
# 195593   2012    2014  December  All India  Combined
# 195594   2012    2014  December  All India  Combined
# 195595   2012    2014  December  All India  Combined
# 195596   2012    2014  December  All India  Combined
# 195597   2012    2014  December  All India  Combined
# 195598   2012    2014  December  All India  Combined
# 195599   2012    2014  December  All India  Combined
#
#                              Group_i                             SubGroup  \
# ...

# %%
data.to_csv(r"C:\Users\himan\Education1\Projects\MoSPI_CPI\Data\merged\cleaned_sheet_cpi_12-24.csv")

# %%
import psycopg2

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215961 entries, 0 to 215960
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   BYear      215961 non-null  int64
#  1   Year_i     215961 non-null  int64
#  2   Month_i    215961 non-null  str
#  3   State_i    215961 non-null  str
#  4   Sector     215961 non-null  str
#  5   Group_i    215961 non-null  str
#  6   SubGroup   215961 non-null  str
#  7   Index_i    215961 non-null  int64
#  8   Inflation  215961 non-null  float64
# dtypes: float64(1), int64(3), str(5)
# memory usage: 14.8 MB

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Himanshu@localhost:5432/mospi")
print("SQLAlchemy connected ✅")
# Out:
# SQLAlchemy connected ✅

# %%
import psycopg2
import pandas as pd

# 1. Load DataFrame
df = pd.read_csv("cleaned_sheet.csv")
print("Worksheet loaded ✅")

# Optional: if you don't want the auto-index column from CSV, uncomment:
# df = df.loc[:, ~df.columns.str.startswith("Unnamed")]

# 2. Connect to PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    database="mospi",
    user="postgres",
    password="12345",
    port="5432"
)
cur = conn.cursor()
print("Connected to PostgreSQL ✅")

# 3. Fixed table name
table_name = "inflation"

# 4. Drop the table if it exists
cur.execute(f"DROP TABLE IF EXISTS {table_name}")
conn.commit()

# 5. Map Pandas dtypes to PostgreSQL
dtype_mapping = {
    "int64": "BIGINT",
    "float64": "DOUBLE PRECISION",
    "object": "TEXT"
}

columns = []
print("\n📌 Column → PostgreSQL type mapping:")
for col, dtype in df.dtypes.items():
    pg_type = dtype_mapping.get(str(dtype), "TEXT")  # fallback: TEXT
    print(f" - {col}: {dtype}  →  {pg_type}")
    columns.append(f'"{col}" {pg_type}')

# Create table with mapped types
create_table_query = f"CREATE TABLE {table_name} ({', '.join(columns)});"
cur.execute(create_table_query)
conn.commit()
print(f"\nTable '{table_name}' created ✅")

# 6. Insert DataFrame data into PostgreSQL (row by row)
num_cols = df.shape[1]
placeholders = ', '.join(['%s'] * num_cols)

# Build column names string, then ESCAPE any literal '%' by doubling them (%%)
col_names = ', '.join([f'"{col}"' for col in df.columns])
safe_col_names = col_names.replace('%', '%%')   # <-- important: escape % in identifiers/text

insert_query = f'INSERT INTO {table_name} ({safe_col_names}) VALUES ({placeholders})'
# Debug print (uncomment if you want to inspect the final query string)
# print("DEBUG INSERT QUERY:", insert_query)

for i, row in enumerate(df.itertuples(index=False, name=None), start=1):
    # optional debug/check:
    # if len(row) != num_cols:
    #     raise RuntimeError(f"Row length {len(row)} != num_cols {num_cols} (row index {i})")

    cur.execute(insert_query, row)

conn.commit()
print("Data inserted into PostgreSQL ✅")

# 7. Verify the data
cur.execute(f"SELECT * FROM {table_name} LIMIT 5;")
rows = cur.fetchall()
print("\nSample data from table:")
for r in rows:
    print(r)

# 8. Close connection
cur.close()
conn.close()
print("\nPostgreSQL connection closed ✅")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 5
#       1 import psycopg2
#       2 import pandas as pd
#       3
#       4 # 1. Load DataFrame
# ----> 5 df = pd.read_csv("cleaned_sheet.csv")
#       6 print("Worksheet loaded ✅")
#       7
#       8 # Optional: if you don't want the auto-index column from CSV, uncomment:
#
# ...
