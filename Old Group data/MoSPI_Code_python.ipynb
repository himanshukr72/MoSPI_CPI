# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv(r"C:\Users\BIT\Desktop\Education 1\Projects\MoSPI\Excel Used\cpi Group data (2).csv")

# %%
data.head(15)
# Out:
#     BaseYear  Year     Month      State    Sector  \
# 0       2012  2025  February  All India  Combined
# 1       2012  2025  February  All India  Combined
# 2       2012  2025  February  All India  Combined
# 3       2012  2025  February  All India  Combined
# 4       2012  2025  February  All India  Combined
# 5       2012  2025  February  All India  Combined
# 6       2012  2025  February  All India  Combined
# 7       2012  2025  February  All India  Combined
# 8       2012  2025  February  All India  Combined
# 9       2012  2025  February  All India  Combined
# 10      2012  2025  February  All India  Combined
# 11      2012  2025  February  All India  Combined
# 12      2012  2025  February  All India  Combined
# 13      2012  2025  February  All India  Combined
# 14      2012  2025  February  All India  Combined
#
#                            Group                             SubGroup  Index  \
# 0             Food and Beverages                 Cereals and Products    200
# 1             Food and Beverages                        Meat and Fish  222.6
# 2             Food and Beverages                                  Egg  196.8
# 3             Food and Beverages                               Fruits  196.8
# 4             Food and Beverages                           Vegetables  193.4
# 5             Food and Beverages                  Pulses and Products  201.9
# 6             Food and Beverages                               Spices  223.9
# 7             Food and Beverages  Prepared Meals, Snacks, Sweets etc.  207.7
# 8             Food and Beverages              Non-alcoholic Beverages  183.7
# 9             Food and Beverages                                    *  197.6
# 10  Pan, Tobacco and Intoxicants                                    *  210.1
# 11         Clothing and Footwear                             Clothing  196.8
# 12         Clothing and Footwear                             Footwear  186.7
# 13         Clothing and Footwear                                    *  195.4
# 14                Fuel and Light                                    *  178.3
#
#    Inflation (%)
# 0            6.1
# 1           2.11
# 2          -3.01
# 3          14.82
# 4          -1.07
# 5          -0.35
# 6          -5.85
# 7           4.16
# 8           3.73
# 9           3.84
# 10          2.39
# 11          2.77
# 12          2.02
# 13          2.68
# 14         -1.33

# %%
data[72897:72920]
# Out:
#        BaseYear  Year Month      State    Sector  \
# 72897      2012  2021   May  Telangana  Combined
# 72898      2012  2021   May  Telangana  Combined
# 72899      2012  2021   May  Telangana  Combined
# 72900      2012  2021   May  Telangana  Combined
# 72901      2012  2021   May  Telangana  Combined
# 72902      2012  2021   May  Telangana  Combined
# 72903      2012  2021   May  Telangana  Combined
# 72904      2012  2021   May  Telangana  Combined
# 72905      2012  2021   May  Telangana     Rural
# 72906      2012  2021   May  Telangana     Rural
# 72907      2012  2021   May  Telangana     Rural
# 72908      2012  2021   May  Telangana     Rural
# 72909      2012  2021   May  Telangana     Rural
# 72910      2012  2021   May  Telangana     Rural
# 72911      2012  2021   May  Telangana     Rural
# 72912      2012  2021   May  Telangana     Rural
# 72913      2012  2021   May  Telangana     Rural
# 72914      2012  2021   May  Telangana     Rural
# 72915      2012  2021   May  Telangana     Rural
# 72916      2012  2021   May  Telangana     Rural
# 72917      2012  2021   May  Telangana     Rural
# 72918      2012  2021   May  Telangana     Rural
# 72919      2012  2021   May  Telangana     Rural
#
#                               Group                             SubGroup  \
# 72897         Clothing and Footwear                             Footwear
# 72898         Clothing and Footwear                                    *
# 72899                Fuel and Light                                    *
# 72900                 Miscellaneous         Household Goods and Services
# 72901                 Miscellaneous                               Health
# 72902                 Miscellaneous          Transport and Communication
# 72903                 Miscellaneous                            Education
# 72904                 Miscellaneous                                    *
# 72905            Food and Beverages                 Cereals and Products
# 72906            Food and Beverages                        Meat and Fish
# 72907            Food and Beverages                                  Egg
# 72908            Food and Beverages                               Fruits
# 72909            Food and Beverages                           Vegetables
# 72910            Food and Beverages                  Pulses and Products
# 72911            Food and Beverages                               Spices
# 72912            Food and Beverages  Prepared Meals, Snacks, Sweets etc.
# 72913            Food and Beverages              Non-alcoholic Beverages
# 72914            Food and Beverages                                    *
# 72915  Pan, Tobacco and Intoxicants                                    *
# 72916         Clothing and Footwear                             Clothing
# 72917         Clothing and Footwear                             Footwear
# 72918         Clothing and Footwear                                    *
# 72919                Fuel and Light                                    *
#
#        Index Inflation (%)
# 72897  152.1   2.217741935
# 72898  164.3   20.27818448
# 72899    142  -24.78813559
# 72900  144.6   3.064861012
# 72901  180.1   34.20268256
# 72902  144.2  -6.180871828
# 72903  165.1   35.43888433
# 72904  158.6   4.136572554
# 72905  161.2  -4.502369668
# 72906  222.3   43.41935484
# 72907    175   30.49962714
# 72908  138.7  -8.929743926
# 72909  114.2   -17.9007908
# 72910  169.3   22.68115942
# 72911  184.8   31.81169757
# 72912  175.9   50.08532423
# 72913  193.3   35.55399719
# 72914  166.7   25.24417731
# 72915  200.5   26.73830594
# 72916  184.8   15.93475533
# 72917  166.6   10.40424122
# 72918  182.2   13.80387258
# 72919  140.9  -1.468531469

# %%
data.isnull().sum()
# Out:
# BaseYear         0
# Year             0
# Month            0
# State            0
# Sector           0
# Group            0
# SubGroup         0
# Index            0
# Inflation (%)    0
# dtype: int64

# %%
data["SubGroup"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_16092\403528206.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["SubGroup"].replace({"*" : np.nan}, inplace=True)

# %%
data["Index"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_16092\1331821987.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Index"].replace({"*" : np.nan}, inplace=True)

# %%
data["Inflation (%)"].replace({"*" : np.nan}, inplace=True)
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_16092\2710611657.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Inflation (%)"].replace({"*" : np.nan}, inplace=True)

# %%
data.tail(15)
# Out:
#         BaseYear  Year    Month        State Sector  \
# 205395      2012  2014  January  West Bengal  Urban
# 205396      2012  2014  January  West Bengal  Urban
# 205397      2012  2014  January  West Bengal  Urban
# 205398      2012  2014  January  West Bengal  Urban
# 205399      2012  2014  January  West Bengal  Urban
# 205400      2012  2014  January  West Bengal  Urban
# 205401      2012  2014  January  West Bengal  Urban
# 205402      2012  2014  January  West Bengal  Urban
# 205403      2012  2014  January  West Bengal  Urban
# 205404      2012  2014  January  West Bengal  Urban
# 205405      2012  2014  January  West Bengal  Urban
# 205406      2012  2014  January  West Bengal  Urban
# 205407      2012  2014  January  West Bengal  Urban
# 205408      2012  2014  January  West Bengal  Urban
# 205409      2012  2014  January  West Bengal  Urban
#
#                                Group                             SubGroup  \
# 205395            Food and Beverages                  Pulses and Products
# 205396            Food and Beverages                               Spices
# 205397            Food and Beverages  Prepared Meals, Snacks, Sweets etc.
# 205398            Food and Beverages              Non-alcoholic Beverages
# 205399            Food and Beverages                                  NaN
# 205400  Pan, Tobacco and Intoxicants                                  NaN
# 205401         Clothing and Footwear                             Clothing
# 205402         Clothing and Footwear                             Footwear
# 205403         Clothing and Footwear                                  NaN
# 205404                Fuel and Light                                  NaN
# 205405                 Miscellaneous         Household Goods and Services
# 205406                 Miscellaneous                               Health
# 205407                 Miscellaneous          Transport and Communication
# 205408                 Miscellaneous                            Education
# 205409                 Miscellaneous                                  NaN
#
#         Index Inflation (%)
# 205395    118          5.45
# 205396  105.9          4.23
# 205397    124         13.66
# 205398    113          7.82
# 205399  121.5         11.88
# 205400  122.2         17.16
# 205401  116.7          10.2
# 205402    112          7.49
# 205403  116.1          9.84
# 205404  115.2          5.88
# 205405  117.4         12.13
# 205406  110.3          5.75
# 205407  111.9          5.27
# 205408  111.5          6.09
# 205409  112.1          6.97

# %%
data[data["Index"] == "*"]
# Out:
# Empty DataFrame
# Columns: [BaseYear, Year, Month, State, Sector, Group, SubGroup, Index, Inflation (%)]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205410 entries, 0 to 205409
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   BaseYear       205410 non-null  int64
#  1   Year           205410 non-null  int64
#  2   Month          205410 non-null  object
#  3   State          205410 non-null  object
#  4   Sector         205410 non-null  object
#  5   Group          205410 non-null  object
#  6   SubGroup       133740 non-null  object
#  7   Index          204131 non-null  object
#  8   Inflation (%)  204156 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 14.1+ MB

# %%
data.isnull().sum()
# Out:
# BaseYear             0
# Year                 0
# Month                0
# State                0
# Sector               0
# Group                0
# SubGroup         71670
# Index             1279
# Inflation (%)     1254
# dtype: int64

# %%
data.loc[data["Group"] == "Food and Beverages", "SubGroup"] = data.loc[data["Group"] == "Food and Beverages", "SubGroup"].fillna("Miscellaneous")

# %%
data[data["Group"] == "Food and Beverages"]
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2025  February    All India  Combined  Food and Beverages
# 1           2012  2025  February    All India  Combined  Food and Beverages
# 2           2012  2025  February    All India  Combined  Food and Beverages
# 3           2012  2025  February    All India  Combined  Food and Beverages
# 4           2012  2025  February    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 205395      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205396      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205397      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205398      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205399      2012  2014   January  West Bengal     Urban  Food and Beverages
#
#                                    SubGroup  Index Inflation (%)
# 0                      Cereals and Products    200           6.1
# 1                             Meat and Fish  222.6          2.11
# 2                                       Egg  196.8         -3.01
# 3                                    Fruits  196.8         14.82
# 4                                Vegetables  193.4         -1.07
# ...                                     ...    ...           ...
# 205395                  Pulses and Products    118          5.45
# 205396                               Spices  105.9          4.23
# 205397  Prepared Meals, Snacks, Sweets etc.    124         13.66
# 205398              Non-alcoholic Beverages    113          7.82
# 205399                        Miscellaneous  121.5         11.88
#
# [94578 rows x 9 columns]

# %%
data.head(10)
# Out:
#    BaseYear  Year     Month      State    Sector               Group  \
# 0      2012  2025  February  All India  Combined  Food and Beverages
# 1      2012  2025  February  All India  Combined  Food and Beverages
# 2      2012  2025  February  All India  Combined  Food and Beverages
# 3      2012  2025  February  All India  Combined  Food and Beverages
# 4      2012  2025  February  All India  Combined  Food and Beverages
# 5      2012  2025  February  All India  Combined  Food and Beverages
# 6      2012  2025  February  All India  Combined  Food and Beverages
# 7      2012  2025  February  All India  Combined  Food and Beverages
# 8      2012  2025  February  All India  Combined  Food and Beverages
# 9      2012  2025  February  All India  Combined  Food and Beverages
#
#                               SubGroup  Index Inflation (%)
# 0                 Cereals and Products    200           6.1
# 1                        Meat and Fish  222.6          2.11
# 2                                  Egg  196.8         -3.01
# 3                               Fruits  196.8         14.82
# 4                           Vegetables  193.4         -1.07
# 5                  Pulses and Products  201.9         -0.35
# 6                               Spices  223.9         -5.85
# 7  Prepared Meals, Snacks, Sweets etc.  207.7          4.16
# 8              Non-alcoholic Beverages  183.7          3.73
# 9                        Miscellaneous  197.6          3.84

# %%
data.iloc[60:80]
# Out:
#     BaseYear  Year     Month                        State    Sector  \
# 60      2012  2025  February  Andaman and Nicobar Islands  Combined
# 61      2012  2025  February  Andaman and Nicobar Islands  Combined
# 62      2012  2025  February  Andaman and Nicobar Islands  Combined
# 63      2012  2025  February  Andaman and Nicobar Islands  Combined
# 64      2012  2025  February  Andaman and Nicobar Islands  Combined
# 65      2012  2025  February  Andaman and Nicobar Islands     Rural
# 66      2012  2025  February  Andaman and Nicobar Islands     Rural
# 67      2012  2025  February  Andaman and Nicobar Islands     Rural
# 68      2012  2025  February  Andaman and Nicobar Islands     Rural
# 69      2012  2025  February  Andaman and Nicobar Islands     Rural
# 70      2012  2025  February  Andaman and Nicobar Islands     Urban
# 71      2012  2025  February  Andaman and Nicobar Islands     Urban
# 72      2012  2025  February  Andaman and Nicobar Islands     Urban
# 73      2012  2025  February  Andaman and Nicobar Islands     Urban
# 74      2012  2025  February  Andaman and Nicobar Islands     Urban
# 75      2012  2025  February               Andhra Pradesh  Combined
# 76      2012  2025  February               Andhra Pradesh  Combined
# 77      2012  2025  February               Andhra Pradesh  Combined
# 78      2012  2025  February               Andhra Pradesh  Combined
# 79      2012  2025  February               Andhra Pradesh  Combined
#
#                            Group              SubGroup  Index Inflation (%)
# 60            Food and Beverages         Miscellaneous  206.5          1.08
# 61  Pan, Tobacco and Intoxicants                   NaN  211.4             0
# 62         Clothing and Footwear                   NaN  183.1          2.58
# 63                Fuel and Light                   NaN    163          4.89
# 64                 Miscellaneous                   NaN  179.5           4.6
# 65            Food and Beverages         Miscellaneous  212.1          0.14
# 66  Pan, Tobacco and Intoxicants                   NaN  203.3         -2.68
# 67         Clothing and Footwear                   NaN  197.5          3.19
# 68                Fuel and Light                   NaN    158          7.19
# 69                 Miscellaneous                   NaN  188.8             3
# 70            Food and Beverages         Miscellaneous  198.6          2.53
# 71  Pan, Tobacco and Intoxicants                   NaN  233.7          6.96
# 72         Clothing and Footwear                   NaN  165.8          1.59
# 73                Fuel and Light                   NaN    170           2.1
# 74                 Miscellaneous                   NaN  172.3          6.03
# 75            Food and Beverages  Cereals and Products  197.8          1.12
# 76            Food and Beverages         Meat and Fish  224.2         -5.72
# 77            Food and Beverages                   Egg  218.7         -6.94
# 78            Food and Beverages                Fruits  199.1         10.67
# 79            Food and Beverages            Vegetables  196.6          1.65

# %%
data.loc[data["Group"] == "Food and Beverages", "SubGroup"] = data.loc[data["Group"] == "Food and Beverages", "SubGroup"].replace(to_replace="Miscellaneous", value= "Residual")

# %%
data
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2025  February    All India  Combined  Food and Beverages
# 1           2012  2025  February    All India  Combined  Food and Beverages
# 2           2012  2025  February    All India  Combined  Food and Beverages
# 3           2012  2025  February    All India  Combined  Food and Beverages
# 4           2012  2025  February    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 205405      2012  2014   January  West Bengal     Urban       Miscellaneous
# 205406      2012  2014   January  West Bengal     Urban       Miscellaneous
# 205407      2012  2014   January  West Bengal     Urban       Miscellaneous
# 205408      2012  2014   January  West Bengal     Urban       Miscellaneous
# 205409      2012  2014   January  West Bengal     Urban       Miscellaneous
#
#                             SubGroup  Index Inflation (%)
# 0               Cereals and Products    200           6.1
# 1                      Meat and Fish  222.6          2.11
# 2                                Egg  196.8         -3.01
# 3                             Fruits  196.8         14.82
# 4                         Vegetables  193.4         -1.07
# ...                              ...    ...           ...
# 205405  Household Goods and Services  117.4         12.13
# 205406                        Health  110.3          5.75
# 205407   Transport and Communication  111.9          5.27
# 205408                     Education  111.5          6.09
# 205409                           NaN  112.1          6.97
#
# [205410 rows x 9 columns]

# %%
data.loc[data["Group"] == "Food and Beverages"]
# Out:
#         BaseYear  Year     Month        State    Sector               Group  \
# 0           2012  2025  February    All India  Combined  Food and Beverages
# 1           2012  2025  February    All India  Combined  Food and Beverages
# 2           2012  2025  February    All India  Combined  Food and Beverages
# 3           2012  2025  February    All India  Combined  Food and Beverages
# 4           2012  2025  February    All India  Combined  Food and Beverages
# ...          ...   ...       ...          ...       ...                 ...
# 205395      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205396      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205397      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205398      2012  2014   January  West Bengal     Urban  Food and Beverages
# 205399      2012  2014   January  West Bengal     Urban  Food and Beverages
#
#                                    SubGroup  Index Inflation (%)
# 0                      Cereals and Products    200           6.1
# 1                             Meat and Fish  222.6          2.11
# 2                                       Egg  196.8         -3.01
# 3                                    Fruits  196.8         14.82
# 4                                Vegetables  193.4         -1.07
# ...                                     ...    ...           ...
# 205395                  Pulses and Products    118          5.45
# 205396                               Spices  105.9          4.23
# 205397  Prepared Meals, Snacks, Sweets etc.    124         13.66
# 205398              Non-alcoholic Beverages    113          7.82
# 205399                             Residual  121.5         11.88
#
# [94578 rows x 9 columns]

# %%
data.loc[data["Group"] == "Pan, Tobacco and Intoxicants", "SubGroup"] = data.loc[data["Group"] == "Pan, Tobacco and Intoxicants", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Clothing and Footwear", "SubGroup"] = data.loc[data["Group"] == "Clothing and Footwear", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Fuel and Light", "SubGroup"] = data.loc[data["Group"] == "Fuel and Light", "SubGroup"].fillna("Residual")

# %%
data.loc[data["Group"] == "Miscellaneous", "SubGroup"] = data.loc[data["Group"] == "Miscellaneous", "SubGroup"].fillna("Residual")

# %%
data[60:80]
# Out:
#     BaseYear  Year     Month                        State    Sector  \
# 60      2012  2025  February  Andaman and Nicobar Islands  Combined
# 61      2012  2025  February  Andaman and Nicobar Islands  Combined
# 62      2012  2025  February  Andaman and Nicobar Islands  Combined
# 63      2012  2025  February  Andaman and Nicobar Islands  Combined
# 64      2012  2025  February  Andaman and Nicobar Islands  Combined
# 65      2012  2025  February  Andaman and Nicobar Islands     Rural
# 66      2012  2025  February  Andaman and Nicobar Islands     Rural
# 67      2012  2025  February  Andaman and Nicobar Islands     Rural
# 68      2012  2025  February  Andaman and Nicobar Islands     Rural
# 69      2012  2025  February  Andaman and Nicobar Islands     Rural
# 70      2012  2025  February  Andaman and Nicobar Islands     Urban
# 71      2012  2025  February  Andaman and Nicobar Islands     Urban
# 72      2012  2025  February  Andaman and Nicobar Islands     Urban
# 73      2012  2025  February  Andaman and Nicobar Islands     Urban
# 74      2012  2025  February  Andaman and Nicobar Islands     Urban
# 75      2012  2025  February               Andhra Pradesh  Combined
# 76      2012  2025  February               Andhra Pradesh  Combined
# 77      2012  2025  February               Andhra Pradesh  Combined
# 78      2012  2025  February               Andhra Pradesh  Combined
# 79      2012  2025  February               Andhra Pradesh  Combined
#
#                            Group              SubGroup  Index Inflation (%)
# 60            Food and Beverages              Residual  206.5          1.08
# 61  Pan, Tobacco and Intoxicants              Residual  211.4             0
# 62         Clothing and Footwear              Residual  183.1          2.58
# 63                Fuel and Light              Residual    163          4.89
# 64                 Miscellaneous              Residual  179.5           4.6
# 65            Food and Beverages              Residual  212.1          0.14
# 66  Pan, Tobacco and Intoxicants              Residual  203.3         -2.68
# 67         Clothing and Footwear              Residual  197.5          3.19
# 68                Fuel and Light              Residual    158          7.19
# 69                 Miscellaneous              Residual  188.8             3
# 70            Food and Beverages              Residual  198.6          2.53
# 71  Pan, Tobacco and Intoxicants              Residual  233.7          6.96
# 72         Clothing and Footwear              Residual  165.8          1.59
# 73                Fuel and Light              Residual    170           2.1
# 74                 Miscellaneous              Residual  172.3          6.03
# 75            Food and Beverages  Cereals and Products  197.8          1.12
# 76            Food and Beverages         Meat and Fish  224.2         -5.72
# 77            Food and Beverages                   Egg  218.7         -6.94
# 78            Food and Beverages                Fruits  199.1         10.67
# 79            Food and Beverages            Vegetables  196.6          1.65

# %%
data.loc[data["Index"].isna(), "Index"] = data["Index"].mode()[0]

# %%
# Step 1: Ensure column is numeric
data["Inflation (%)"] = pd.to_numeric(data["Inflation (%)"], errors="coerce")

# Step 2: Fill NaN values with median using loc
data.loc[data["Inflation (%)"].isna(), "Inflation (%)"] = data["Inflation (%)"].median()

# %%
data[203955:203975]
# Out:
#         BaseYear  Year    Month              State    Sector  \
# 203955      2012  2014  January  Arunachal Pradesh  Combined
# 203956      2012  2014  January  Arunachal Pradesh  Combined
# 203957      2012  2014  January  Arunachal Pradesh  Combined
# 203958      2012  2014  January  Arunachal Pradesh  Combined
# 203959      2012  2014  January  Arunachal Pradesh  Combined
# 203960      2012  2014  January  Arunachal Pradesh     Rural
# 203961      2012  2014  January  Arunachal Pradesh     Rural
# 203962      2012  2014  January  Arunachal Pradesh     Rural
# 203963      2012  2014  January  Arunachal Pradesh     Rural
# 203964      2012  2014  January  Arunachal Pradesh     Rural
# 203965      2012  2014  January  Arunachal Pradesh     Urban
# 203966      2012  2014  January  Arunachal Pradesh     Urban
# 203967      2012  2014  January  Arunachal Pradesh     Urban
# 203968      2012  2014  January  Arunachal Pradesh     Urban
# 203969      2012  2014  January  Arunachal Pradesh     Urban
# 203970      2012  2014  January              Assam  Combined
# 203971      2012  2014  January              Assam  Combined
# 203972      2012  2014  January              Assam  Combined
# 203973      2012  2014  January              Assam  Combined
# 203974      2012  2014  January              Assam  Combined
#
#                                Group              SubGroup  Index  \
# 203955            Food and Beverages              Residual  123.4
# 203956  Pan, Tobacco and Intoxicants              Residual  123.4
# 203957         Clothing and Footwear              Residual  123.4
# 203958                Fuel and Light              Residual  123.4
# 203959                 Miscellaneous              Residual  123.4
# 203960            Food and Beverages              Residual  114.7
# 203961  Pan, Tobacco and Intoxicants              Residual  112.4
# 203962         Clothing and Footwear              Residual  122.8
# 203963                Fuel and Light              Residual  114.6
# 203964                 Miscellaneous              Residual  111.9
# 203965            Food and Beverages              Residual  123.4
# 203966  Pan, Tobacco and Intoxicants              Residual  123.4
# 203967         Clothing and Footwear              Residual  123.4
# 203968                Fuel and Light              Residual  123.4
# 203969                 Miscellaneous              Residual  123.4
# 203970            Food and Beverages  Cereals and Products  116.4
# 203971            Food and Beverages         Meat and Fish  112.8
# 203972            Food and Beverages                   Egg  116.7
# 203973            Food and Beverages                Fruits  120.6
# 203974            Food and Beverages            Vegetables  122.7
#
#         Inflation (%)
# 203955           4.89
# 203956           4.89
# 203957           4.89
# 203958           4.89
# 203959           4.89
# 203960           7.20
# 203961           5.05
# 203962          14.34
# 203963           9.35
# 203964           6.88
# 203965           4.89
# 203966           4.89
# 203967           4.89
# 203968           4.89
# 203969           4.89
# 203970          11.82
# 203971          10.37
# 203972          10.09
# 203973          18.00
# 203974          18.21

# %%
data.to_csv("cleaned_sheet.csv")
